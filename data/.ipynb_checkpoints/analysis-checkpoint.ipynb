# %%
import pandas as pd
import matplotlib.pyplot as plt
filepath = "/home/harshavardan/Desktop/gitrepos/classical-conditioning/data/201009/F2/"

# %%
trials = pd.read_csv(filepath + "trial.csv", header = None)[0]
trials
# Out:
# 0     precs
# 1     precs
# 2     precs
# 3     precs
# 4     precs
#       ...
# 75     test
# 76     test
# 77     test
# 78     test
# 79     test
# Name: 0, Length: 80, dtype: object

# %%
precs = []
preus = []
train = []
probe = []
test = []

for i in range(len(trials)):
    if trials[i] == "precs":
        precs.append(i + 1)
    elif trials[i] == "preus":
        preus.append(i + 1)
    elif trials[i] == "training":
        train.append(i + 1)
    elif trials[i] == "probe":
        probe.append(i + 1)
    elif trials[i] == "test":
        test.append(i + 1)

# %%
time = []
for i in range(800):
    time.append(i / 200.0 * 1000)

# %%
keyword = "train"
plt.figure(figsize = (20, 10))
for i in train:
    plt.plot(time, pd.read_csv(filepath + "rawMotion" + str(i) + ".csv")[:800], color = "gray", alpha = 0.5)
    plt.ylim(0, 10)
    plt.xlabel("Time (ms)")
    plt.ylabel("Motion (arbitrary units)")
    plt.title(keyword)
    
avg = [0] * 800
for i in train:
    k = 0
    for j in pd.read_csv(filepath + "rawMotion" + str(i) + ".csv")[pd.read_csv(filepath + "rawMotion" + str(i) + ".csv").columns[0]][:800]:
        avg[k] = avg[k] + j/len(train)
        k = k + 1
        
plt.ylim(0, 5)
plt.xlim(0,4000)
plt.plot(time, avg[:800], "k")
plt.axvspan(0, 4000, alpha = 0.5, color = 'lightblue')
plt.axvspan(2000, 2050, alpha = 1, color = 'red')

plt.savefig(filepath + "keyword.png")

# %%
keyword = "probe"
plt.figure(figsize = (20, 10))
for i in probe:
    plt.plot(time, pd.read_csv(filepath + "rawMotion" + str(i) + ".csv")[:800], color = "gray", alpha = 0.5)
    plt.ylim(0, 10)
    plt.xlabel("Time (ms)")
    plt.ylabel("Motion (arbitrary units)")
    plt.title(keyword)
    
avg = [0] * 800
for i in probe:
    k = 0
    for j in pd.read_csv(filepath + "rawMotion" + str(i) + ".csv")[pd.read_csv(filepath + "rawMotion" + str(i) + ".csv").columns[0]][:800]:
        avg[k] = avg[k] + j/len(probe)
        k = k + 1
        
plt.ylim(0, 5)
plt.xlim(0,4000)
plt.plot(time, avg[:800], "k")
plt.axvspan(0, 4000, alpha = 0.5, color = 'lightblue')
plt.axvspan(2000, 2050, alpha = 1, color = 'red')

plt.savefig(filepath + "keyword.png")

# %%
plt.figure(figsize = (20, 10))
plt.plot(avg[400:425])

# %%
for i in probe:
    plt.plot(time, pd.read_csv(filepath + "rawMotion" + str(i) + ".csv")[:800], color = "gray", alpha = 0.5)
    plt.ylim(0, 10)
    plt.xlabel("Time (ms)")
    plt.ylabel("Motion (arbitrary units)")
    plt.title(i)
    plt.show()

# %%
plt.figure(figsize = (20, 10))
plt.ylim(0, 5)
plt.xlim(1900,2200)
plt.plot(time, avg[:800], "k")
plt.axvspan(0, 4000, alpha = 0.5, color = 'lightblue')
plt.axvspan(2000, 2050, alpha = 1, color = 'red')
