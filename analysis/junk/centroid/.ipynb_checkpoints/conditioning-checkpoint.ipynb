# %%
import csv
import matplotlib.pyplot as plt
import pandas as pd
import statistics as stats
import scipy.signal
import matplotlib.axes as maxes
import numpy as np
from operator import add

# %%
dist = []
for i in [2, 3, 4, 6, 7, 8, 9]:
    x = []
    y = []
    temp_dist = []
    count = 0
    with open("./centroid" + str(i) + ".csv") as csv_file:
        csv_reader = csv.reader(csv_file, delimiter = ",")
        for row in csv_reader:
            if count == 1501:
                break
            count += 1
            x.append(row[0])
            y.append(row[1])
            if len(x) <=1:
                pass
            else:
                temp_dist.append(((float(x[-1]) - float(x[-2]))**2 + (float(y[-1]) - float(y[-2]))**2)**0.5)
    dist.append(temp_dist)

# %%
for i in range(len(dist)):
    for j in range(len(dist[i])):
        if dist[i][j] <= 0:
            dist[i][j] = 0

# %%
plt.figure(figsize = (20, 5))
for i in range(len(dist)):
    dist[i] = pd.Series(dist[i])
    dist[i] = dist[i].rolling(1).mean()
    plt.plot(dist[i], "gray", linewidth = 0.8)
    plt.fill_between((500, 900), (30, 30), color = "lightblue")
    plt.fill_between((890, 900), (30, 30), color = "red", alpha = 0.5)
    plt.xlim(100, 1300)

avg = []
for i in range(len(dist[0])):
    temp = []
    for j in range(len(dist)):
        temp.append(dist[j][i])
    avg.append(stats.mean(temp))

plt.plot(avg, "k", linewidth = 3)
plt.ylim(0, max(avg) * 1.1)
# Out:
# (0, 13.355689483742884)

# %%
for i in range(len(dist)):
    plt.figure(figsize = (20, 5))
    plt.plot(dist[i], "k")
    plt.ylim(0, 30)
    plt.fill_between((500, 900), (30, 30), color = "lightblue")
    plt.fill_between((890, 900), (30, 30), color = "red", alpha = 0.5)
    plt.show()

# %%
for i in range(len(dist)):
    dist[i] = pd.Series(dist[i])
    dist[i] = dist[i].rolling(15).mean()

# %%
for i in range(len(dist)):
    plt.figure(figsize = (20, 5))
    plt.plot(dist[i], "k")
    plt.ylim(0, 30)
    plt.fill_between((500, 900), (30, 30), color = "lightblue")
    plt.fill_between((890, 900), (30, 30), color = "red", alpha = 0.5)
    plt.show()

# %%
plt.figure(figsize = (20, 10))
for i in range(len(dist)):
    plt.plot((stats.mean(dist[i][100:490]), stats.mean(dist[i][500:890]), stats.mean(dist[i][890:1280])),
             "lightgray")
plt.plot((stats.mean(avg[100:490]), stats.mean(avg[500:890]), stats.mean(avg[890:1280])), "k")
plt.ylim(0, )
# Out:
# (0, 2.199204790738058)

# %%
all_peaks = []
for i in range(len(dist)):
    peaks, _ = scipy.signal.find_peaks(dist[i], height = 2, width = 7)
    plt.figure(figsize = (20, 5))
    plt.plot(dist[i], "k")
    plt.plot(dist[i][peaks], "x", color = "r")
    plt.ylim(0, 30)
    plt.fill_between((510, 910), (30, 30), color = "lightblue")
    plt.fill_between((900, 910), (30, 30), color = "red", alpha = 0.5)
    plt.show()
    all_peaks.append(peaks)

# %%
plt.figure(figsize = (20, 5))
plt.eventplot(all_peaks)
# Out:
# [<matplotlib.collections.EventCollection at 0x7f0c7c0daf70>,
#  <matplotlib.collections.EventCollection at 0x7f0c7c0daf10>,
#  <matplotlib.collections.EventCollection at 0x7f0c7c0daf40>,
#  <matplotlib.collections.EventCollection at 0x7f0c7dcaed30>,
#  <matplotlib.collections.EventCollection at 0x7f0c7dcaec40>,
#  <matplotlib.collections.EventCollection at 0x7f0c7dcae880>,
#  <matplotlib.collections.EventCollection at 0x7f0c7dcae4f0>]

# %%
avg = [0, 0, 0]
for i in range(len(all_peaks)):
    peak_count = [0, 0, 0]
    for j in all_peaks[i]:
        if (j < 490) & (j >= 90):
            peak_count[0] +=1
        elif (j < 890) & (j >= 490):
            peak_count[1] += 1
        elif (j < 1290) & (j >= 890):
            peak_count[2] += 1
    plt.plot(peak_count, "lightgray")
    avg = list(map(add, avg, peak_count))
plt.xticks([0, 1, 2])

for i in range(len(avg)):
    avg[i] = avg[i] / len(all_peaks)

plt.plot(avg, "x", color = "k")
plt.plot(avg, color = "k")
